# %%
import xml.etree.ElementTree as ET
from nltk import word_tokenize, RegexpTokenizer, FreqDist
import nltk.classify
from nltk.classify import maxent
import random
import math
from nltk.corpus import stopwords
from pprint import pprint
import numpy as np
stpwords = stopwords.words('english')
import re
import pickle
import sys
from nltk import ngrams


## extra output for debugging
debug = 1






def first_pass(train_xml, test_xml, num_features=100):
    train, Ytrain, test, Ytest = revs_labels(train_xml, test_xml)

    all_words, all_bigrams, all_trigrams, feat_words, feat_bigrams, feat_trigrams = get_vocab(train, num_features)

    x_feat_list = features(train, feat_words, feat_bigrams, feat_trigrams)
    y_feat_list = features(test, feat_words, feat_bigrams, feat_trigrams)
    test_zip = list(zip (y_feat_list, Ytest))
    train_zip = list(zip (x_feat_list, Ytrain))

    model, pred = run_model(train_zip, test_zip)
    return model

def second_pass(train_xml, test_xml, feat_words):
    train, Ytrain, test, Ytest = revs_labels(train_xml, test_xml)

    x_feat_list = features(train, feat_words, feat_bigrams, feat_trigrams)
    y_feat_list = features(test, feat_words, feat_bigrams, feat_trigrams)
    test_zip = list(zip (y_feat_list, Ytest))
    train_zip = list(zip (x_feat_list, Ytrain))

    model, pred = run_model(train_zip, test_zip)
    return model

# %%
# if len(sys.argv) > 1:
#     trainfile = sys.argv[1]
# elif len(sys.argv) > 2:
#     testfile = sys.argv[2]
# else:
trainfile = "TrainingSet.xml"


tree = ET.parse(trainfile)
root = tree.getroot()
root = [rev for rev in root]
random.shuffle(root, lambda: 0.424125125437)

train_xml = root[:1800]
test_xml = root[1800:]
# train_xml = root[:20]
# test_xml = root[1890:]
if debug: print(len(root), len(train_xml), len(test_xml))
# Out:
# 1900 1800 100

# %%
def revs_labels(train_xml, test_xml):
    train  = [0] * len(train_xml)
    Ytrain = [0] * len(train_xml)
    train_ID = [0] * len(train_xml)
    for i in range(len(train_xml)):
        train[i] = train_xml[i].find("review_text").text.lower()
        y = float(train_xml[i].find("rating").text)
        if (y < 3):
            Ytrain[i] = 'neg'
        else:
            Ytrain[i] = 'pos'
        train_ID[i] = train_xml[i].find("unique_id").text


    # train[0].find("review_text").text
    test  = [0] * len(test_xml)
    Ytest = [0] * len(test_xml)
    test_ID  = [0] * len(test_xml)
    for i in range(len(test_xml)):
        test[i] = test_xml[i].find("review_text").text.lower()
        Ytest[i] = str(int(float(test_xml[i].find("rating").text)))
        y = float(test_xml[i].find("rating").text)
        if (y < 3):
            Ytest[i] = 'neg'
        else:
            Ytest[i] = 'pos'
        test_ID[i] = test_xml[i].find("unique_id").text
    return train, Ytrain, train_ID, test, Ytest, test_ID


def get_vocab(train, num_words=500, num_bigrams=50, num_trigrams=10):
    tokenizer = RegexpTokenizer(r'[a-z][a-z\']*').tokenize
    tokenized = [tokenizer(rev) for rev in train]

    all_words = [x for rev in tokenized for x in rev]
    all_words = [x for x in all_words if x not in stpwords]
    all_bigrams = list(ngrams(all_words, 2))
    all_trigrams = list(ngrams(all_words, 3))

    word_fdist = FreqDist(all_words)
    bigram_fdist = FreqDist(all_bigrams)
    trigram_fdist = FreqDist(all_trigrams)

    feat_words = word_fdist.most_common(num_words)
    feat_bigrams = bigram_fdist.most_common(num_bigrams)
    feat_trigrams = trigram_fdist.most_common(num_trigrams)

    feat_words = [a for a,b in feat_words]
    feat_bigrams = [a for a,b in feat_bigrams]
    feat_trigrams = [a for a,b in feat_trigrams]


    return all_words, all_bigrams, all_trigrams, feat_words, feat_bigrams, feat_trigrams
#     return all_words, all_bigrams, feat_words, feat_bigrams



def features (revs, words, bigrams, trigrams):
    feat_list = []
    tokenizer = RegexpTokenizer(r'[a-z][a-z\']*').tokenize
    for text in revs:
        feat = {}
        tokens = [x for x in tokenizer(text) if x not in stpwords]
        text_bigrams = list(ngrams(tokens, 2))
        text_trigrams = list(ngrams(tokens, 3))
#         print(text_trigrams)
        for bg in bigrams:
            feat[bg] = int(bg in text_bigrams)
        for tg in trigrams:
            feat[tg] = int(tg in text_trigrams)
        for word in words:
            feat[word] = int(word in text)
        feat_list.append(feat)

    return feat_list

def find_best_feats(model, num_features=100):
    from contextlib import redirect_stdout
    ## nltk's most informative features prints to std out
    #  extract labels from output

    with open('help.txt', 'w') as f:
        with redirect_stdout(f):
            model.show_most_informative_features(300)
    with open('help.txt', 'r') as f:
        idk = re.findall(u'\s[a-z][a-z\']*=', f.read())

        idk = [re.findall(u'[a-z\']+', s) for s in idk]
        idk = [x for y in idk for x in y]
    with open('most_helpful.txt', 'wb') as f:
        pickle.dump(idk, f)
    return idk



[1, 2, 3, 4]
def check_acc(pred, Ytest):
    thing = list(zip(pred, Ytest))

    correct = 0
    total = 0
    for (p,r) in thing:
        if p == r:
            correct += 1
    #         print("correct", p,r)
        else:
    #         print("incorrect", p,r)
            total += 1
    #     print(p,r)
    print(correct, total)
    # pprint(thing)

if debug > 1:
    print(Ytrain.count('pos'),Ytrain.count('neg'), len(Ytrain))
    print(Ytest.count('pos'),Ytest.count('neg'), len(Ytest))

    print(Ytrain[:150])
     #pprint(list(zip(Ytrain[250:255],train[250:255])))

def run_model(train_zip, test_zip):
    encoding = maxent.TypedMaxentFeatureEncoding.train(train_zip)

    v = .01
    model = maxent.MaxentClassifier.train(train_zip, encoding=encoding, trace=4, min_lldelta=v)
    print(nltk.classify.accuracy(model, test_zip))
    # pred = model.classify_many(y_feat_list)
    pred = []
    return model, pred

# %%
train, Ytrain, train_ID, test, Ytest, test_ID = revs_labels(train_xml, test_xml)

# %%
num_features = 55
num_bigrams = 90
num_trigrams = 8
all_words, all_bigrams, all_trigrams, feat_words, feat_bigrams, feat_trigrams = get_vocab(train, num_features, num_bigrams, num_trigrams)
# all_words, all_bigrams, feat_words, feat_bigrams = get_vocab(train, num_features, num_bigrams)

# %%
x_feat_list = features(train, feat_words, feat_bigrams, feat_trigrams)
y_feat_list = features(test, feat_words, feat_bigrams, feat_trigrams)
test_zip = list(zip (y_feat_list, Ytest))
train_zip = list(zip (x_feat_list, Ytrain))

model, pred = run_model(train_zip, test_zip)
#     return model
# x_feat_list
# Out:
#   ==> Training (100 iterations)
#
#       Iteration    Log Likelihood    Accuracy
#       ---------------------------------------
#              1          -0.69315        0.504
#              2          -0.67064        0.687
#              3          -0.65132        0.703
#              4          -0.63469        0.707
#              5          -0.62036        0.705
#              6          -0.60794        0.705
#              7          -0.59712        0.709
#          Final          -0.58759        0.710
# 0.69

# %%
model.show_most_informative_features(300)
# Out:
#   -0.726 ('must', 'read')==<class 'int'> and label is 'neg'
#   -0.710 ('waste', 'time')==<class 'int'> and label is 'pos'
#   -0.632 boring==<class 'int'> and label is 'pos'
#   -0.525 ('highly', 'recommend', 'book')==<class 'int'> and label is 'neg'
#   -0.497 ('highly', 'recommended')==<class 'int'> and label is 'neg'
#   -0.366 ("don't", 'buy')==<class 'int'> and label is 'pos'
#   -0.348 ('highly', 'recommend')==<class 'int'> and label is 'neg'
#   -0.342 ('one', 'best')==<class 'int'> and label is 'neg'
#   -0.328 waste==<class 'int'> and label is 'pos'
#   -0.293 ('must', 'read', 'book')==<class 'int'> and label is 'neg'
#   -0.272 ('much', 'better')==<class 'int'> and label is 'pos'
#   -0.238 ('book', 'great')==<class 'int'> and label is 'neg'
#   -0.237 ('save', 'money')==<class 'int'> and label is 'pos'
#   -0.233 excellent==<class 'int'> and label is 'neg'
#   -0.222 ('half', 'book')==<class 'int'> and label is 'pos'
#   -0.214 ('easy', 'read')==<class 'int'> and label is 'neg'
#   -0.188 ('great', 'book')==<class 'int'> and label is 'neg'
#   -0.187 wonderful==<class 'int'> and label is 'neg'
#   -0.173 ('recommend', 'book', 'anyone')==<class 'int'> and label is 'neg'
#   -0.172 poor==<class 'int'> and label is 'pos'
#   -0.171 ('book', 'anyone')==<class 'int'> and label is 'neg'
#   -0.161 ('character', 'development')==<class 'int'> and label is 'pos'
#   -0.158 favorite==<class 'int'> and label is 'neg'
#   -0.157 unfortunately==<class 'int'> and label is 'pos'
#   -0.141 worst==<class 'int'> and label is 'pos'
#   -0.140 recommended==<class 'int'> and label is 'neg'
#   -0.138 useful==<class 'int'> and label is 'pos'
#   -0.136 bad==<class 'int'> and label is 'pos'
#    0.134 ('must', 'read')==<class 'int'> and label is 'pos'
#   -0.131 recipes==<class 'int'> and label is 'neg'
#   -0.129 disappointed==<class 'int'> and label is 'pos'
#   -0.118 ('like', 'book')==<class 'int'> and label is 'pos'
#   -0.118 ('book', 'well')==<class 'int'> and label is 'neg'
#   -0.116 amazing==<class 'int'> and label is 'neg'
#   -0.116 ("i've", 'ever', 'read')==<class 'int'> and label is 'neg'
#   -0.108 instead==<class 'int'> and label is 'pos'
#   -0.106 ('end', 'book')==<class 'int'> and label is 'pos'
#    0.106 ('world', 'war', 'ii')==<class 'int'> and label is 'neg'
#   -0.105 ('bought', 'book')==<class 'int'> and label is 'pos'
#   -0.104 shows==<class 'int'> and label is 'neg'
#   -0.102 ('book', 'found')==<class 'int'> and label is 'pos'
#   -0.099 fascinating==<class 'int'> and label is 'neg'
#    0.099 ('world', 'war', 'ii')==<class 'int'> and label is 'pos'
#    0.098 boring==<class 'int'> and label is 'neg'
#    0.098 ('middle', 'east')==<class 'int'> and label is 'pos'
#    0.096 ('good', 'read')==<class 'int'> and label is 'pos'
#   -0.096 ('recommend', 'book')==<class 'int'> and label is 'neg'
#    0.095 ('would', 'like')==<class 'int'> and label is 'pos'
#    0.095 ('would', 'like')==<class 'int'> and label is 'neg'
#    0.094 ("don't", 'buy')==<class 'int'> and label is 'neg'
#    0.094 ('highly', 'recommended')==<class 'int'> and label is 'pos'
#   -0.093 half==<class 'int'> and label is 'pos'
#   -0.092 loved==<class 'int'> and label is 'neg'
#   -0.089 ("don't", 'think')==<class 'int'> and label is 'pos'
#   -0.089 easy==<class 'int'> and label is 'neg'
#    0.088 ('great', 'book')==<class 'int'> and label is 'pos'
#    0.086 excellent==<class 'int'> and label is 'pos'
#    0.085 ('book', 'great')==<class 'int'> and label is 'pos'
#   -0.083 trying==<class 'int'> and label is 'pos'
#    0.082 europe==<class 'int'> and label is 'pos'
#    0.082 ('middle', 'east')==<class 'int'> and label is 'neg'
#   -0.082 totally==<class 'int'> and label is 'pos'
#    0.081 ('book', 'would')==<class 'int'> and label is 'neg'
#   -0.080 process==<class 'int'> and label is 'neg'
#    0.080 ('must', 'read', 'book')==<class 'int'> and label is 'pos'
#    0.079 easy==<class 'int'> and label is 'pos'
#    0.078 ('highly', 'recommend', 'book')==<class 'int'> and label is 'pos'
#    0.078 ('much', 'better')==<class 'int'> and label is 'neg'
#    0.077 ('waste', 'time')==<class 'int'> and label is 'neg'
#   -0.077 ('well', 'written')==<class 'int'> and label is 'neg'
#    0.077 ('highly', 'recommend')==<class 'int'> and label is 'pos'
#   -0.076 recommend==<class 'int'> and label is 'neg'
#    0.076 ('united', 'states')==<class 'int'> and label is 'neg'
#   -0.076 beautiful==<class 'int'> and label is 'neg'
#   -0.075 didn't==<class 'int'> and label is 'pos'
#    0.075 waste==<class 'int'> and label is 'neg'
#    0.075 saying==<class 'int'> and label is 'neg'
#    0.075 ('good', 'read')==<class 'int'> and label is 'neg'
#    0.074 author's==<class 'int'> and label is 'neg'
#    0.074 ('one', 'best')==<class 'int'> and label is 'pos'
#   -0.074 don't==<class 'int'> and label is 'pos'
#   -0.074 ('first', 'time')==<class 'int'> and label is 'neg'
#    0.074 wonderful==<class 'int'> and label is 'pos'
#    0.073 poor==<class 'int'> and label is 'neg'
#   -0.073 definitely==<class 'int'> and label is 'neg'
#    0.073 claims==<class 'int'> and label is 'neg'
#    0.073 ('half', 'book')==<class 'int'> and label is 'neg'
#    0.073 favorite==<class 'int'> and label is 'pos'
#    0.072 ('save', 'money')==<class 'int'> and label is 'neg'
#   -0.072 material==<class 'int'> and label is 'pos'
#    0.071 ('book', 'anyone')==<class 'int'> and label is 'pos'
#    0.071 ('easy', 'read')==<class 'int'> and label is 'pos'
#    0.070 recipes==<class 'int'> and label is 'pos'
#   -0.070 jesus==<class 'int'> and label is 'pos'
#   -0.070 ("i've", 'read')==<class 'int'> and label is 'pos'
#    0.069 ('book', 'well')==<class 'int'> and label is 'pos'
#   -0.069 ("i'm", 'going')==<class 'int'> and label is 'pos'
#    0.068 ('recommend', 'book', 'anyone')==<class 'int'> and label is 'pos'
#    0.067 military==<class 'int'> and label is 'pos'
#    0.067 covers==<class 'int'> and label is 'pos'
#   -0.067 ('good', 'book')==<class 'int'> and label is 'neg'
#    0.066 crime==<class 'int'> and label is 'pos'
#   -0.066 i'm==<class 'int'> and label is 'pos'
#   -0.065 ("i've", 'ever')==<class 'int'> and label is 'neg'
#    0.065 amazing==<class 'int'> and label is 'pos'
#    0.065 ('united', 'states')==<class 'int'> and label is 'pos'
#   -0.065 enjoyed==<class 'int'> and label is 'neg'
#    0.064 ('character', 'development')==<class 'int'> and label is 'neg'
#    0.064 military==<class 'int'> and label is 'neg'
#   -0.064 reviews==<class 'int'> and label is 'pos'
#    0.064 provides==<class 'int'> and label is 'pos'
#   -0.063 experience==<class 'int'> and label is 'neg'
#   -0.063 highly==<class 'int'> and label is 'neg'
#   -0.063 ('buy', 'book')==<class 'int'> and label is 'neg'
#    0.062 century==<class 'int'> and label is 'pos'
#   -0.062 wouldn't==<class 'int'> and label is 'pos'
#    0.062 gives==<class 'int'> and label is 'pos'
#    0.062 ("i've", 'ever', 'read')==<class 'int'> and label is 'pos'
#    0.062 ('even', 'though')==<class 'int'> and label is 'pos'
#    0.062 disappointed==<class 'int'> and label is 'neg'
#   -0.062 love==<class 'int'> and label is 'neg'
#   -0.061 anything==<class 'int'> and label is 'pos'
#    0.061 ('throughout', 'book')==<class 'int'> and label is 'pos'
#    0.061 recommended==<class 'int'> and label is 'pos'
#    0.061 worst==<class 'int'> and label is 'neg'
#    0.060 ('throughout', 'book')==<class 'int'> and label is 'neg'
#    0.060 ('book', 'found')==<class 'int'> and label is 'neg'
#    0.060 highly==<class 'int'> and label is 'pos'
#    0.060 ('like', 'book')==<class 'int'> and label is 'neg'
#    0.060 useful==<class 'int'> and label is 'neg'
#    0.060 questions==<class 'int'> and label is 'pos'
#    0.060 future==<class 'int'> and label is 'pos'
#   -0.059 guy==<class 'int'> and label is 'pos'
#    0.059 ('bought', 'book')==<class 'int'> and label is 'neg'
#   -0.059 nearly==<class 'int'> and label is 'pos'
#    0.059 bad==<class 'int'> and label is 'neg'
#   -0.059 mr==<class 'int'> and label is 'pos'
#   -0.059 ('book', 'ever', 'read')==<class 'int'> and label is 'pos'
#   -0.059 doesn't==<class 'int'> and label is 'pos'
#   -0.058 ("don't", 'know')==<class 'int'> and label is 'pos'
#    0.058 details==<class 'int'> and label is 'pos'
#    0.057 unfortunately==<class 'int'> and label is 'neg'
#   -0.057 ('book', 'author')==<class 'int'> and label is 'pos'
#    0.056 whether==<class 'int'> and label is 'pos'
#    0.056 ('well', 'written')==<class 'int'> and label is 'pos'
#   -0.056 i'll==<class 'int'> and label is 'pos'
#    0.055 due==<class 'int'> and label is 'pos'
#   -0.055 food==<class 'int'> and label is 'neg'
#    0.055 ('book', 'would')==<class 'int'> and label is 'pos'
#    0.055 nature==<class 'int'> and label is 'pos'
#   -0.054 best==<class 'int'> and label is 'neg'
#   -0.054 christian==<class 'int'> and label is 'pos'
#    0.054 shows==<class 'int'> and label is 'pos'
#    0.054 analysis==<class 'int'> and label is 'pos'
#    0.054 definitely==<class 'int'> and label is 'pos'
#    0.054 ('good', 'book')==<class 'int'> and label is 'pos'
#    0.054 needs==<class 'int'> and label is 'neg'
#   -0.054 means==<class 'int'> and label is 'neg'
#    0.053 ('even', 'though')==<class 'int'> and label is 'neg'
#    0.053 indeed==<class 'int'> and label is 'neg'
#   -0.053 open==<class 'int'> and label is 'neg'
#    0.053 historical==<class 'int'> and label is 'pos'
#    0.053 loved==<class 'int'> and label is 'pos'
#    0.053 fascinating==<class 'int'> and label is 'pos'
#   -0.052 ('go', 'back')==<class 'int'> and label is 'pos'
#    0.052 level==<class 'int'> and label is 'pos'
#    0.052 money==<class 'int'> and label is 'neg'
#    0.052 game==<class 'int'> and label is 'pos'
#   -0.052 history==<class 'int'> and label is 'neg'
#   -0.052 finish==<class 'int'> and label is 'pos'
#   -0.052 parents==<class 'int'> and label is 'neg'
#    0.051 wanted==<class 'int'> and label is 'neg'
#    0.051 spend==<class 'int'> and label is 'neg'
#   -0.051 ('book', 'also')==<class 'int'> and label is 'neg'
#    0.051 important==<class 'int'> and label is 'pos'
#    0.051 especially==<class 'int'> and label is 'pos'
#    0.051 argument==<class 'int'> and label is 'neg'
#    0.051 instead==<class 'int'> and label is 'neg'
#    0.051 ('buy', 'book')==<class 'int'> and label is 'pos'
#   -0.050 including==<class 'int'> and label is 'neg'
#   -0.050 working==<class 'int'> and label is 'neg'
#    0.050 totally==<class 'int'> and label is 'neg'
#    0.049 attention==<class 'int'> and label is 'neg'
#    0.049 half==<class 'int'> and label is 'neg'
#    0.049 completely==<class 'int'> and label is 'neg'
#    0.049 reference==<class 'int'> and label is 'pos'
#   -0.049 buy==<class 'int'> and label is 'pos'
#   -0.049 ('real', 'life')==<class 'int'> and label is 'neg'
#    0.049 pages==<class 'int'> and label is 'neg'
#   -0.049 overall==<class 'int'> and label is 'neg'
#    0.049 dead==<class 'int'> and label is 'pos'
#    0.049 ('recommend', 'book')==<class 'int'> and label is 'pos'
#    0.049 lack==<class 'int'> and label is 'neg'
#    0.048 provide==<class 'int'> and label is 'pos'
#    0.048 states==<class 'int'> and label is 'neg'
#   -0.048 ('would', 'recommend', 'book')==<class 'int'> and label is 'pos'
#    0.048 crime==<class 'int'> and label is 'neg'
#    0.048 serious==<class 'int'> and label is 'neg'
#    0.048 alone==<class 'int'> and label is 'pos'
#    0.048 living==<class 'int'> and label is 'pos'
#    0.047 single==<class 'int'> and label is 'pos'
#    0.047 relationship==<class 'int'> and label is 'pos'
#    0.047 power==<class 'int'> and label is 'pos'
#   -0.047 edition==<class 'int'> and label is 'neg'
#    0.047 ("i've", 'ever')==<class 'int'> and label is 'pos'
#    0.047 culture==<class 'int'> and label is 'pos'
#    0.047 social==<class 'int'> and label is 'pos'
#   -0.046 point==<class 'int'> and label is 'pos'
#   -0.046 great==<class 'int'> and label is 'neg'
#    0.046 enjoyed==<class 'int'> and label is 'pos'
#    0.046 evil==<class 'int'> and label is 'pos'
#    0.046 recommend==<class 'int'> and label is 'pos'
#    0.046 mention==<class 'int'> and label is 'neg'
#   -0.046 lack==<class 'int'> and label is 'pos'
#   -0.045 ("i'm", 'sure')==<class 'int'> and label is 'pos'
#    0.045 material==<class 'int'> and label is 'neg'
#    0.045 middle==<class 'int'> and label is 'neg'
#    0.045 process==<class 'int'> and label is 'pos'
#    0.045 issues==<class 'int'> and label is 'pos'
#    0.045 beautiful==<class 'int'> and label is 'pos'
#   -0.045 learn==<class 'int'> and label is 'neg'
#   -0.045 friends==<class 'int'> and label is 'neg'
#    0.045 wants==<class 'int'> and label is 'pos'
#    0.044 ('end', 'book')==<class 'int'> and label is 'neg'
#   -0.044 keep==<class 'int'> and label is 'neg'
#    0.044 light==<class 'int'> and label is 'pos'
#   -0.044 whole==<class 'int'> and label is 'pos'
#    0.044 evidence==<class 'int'> and label is 'pos'
#   -0.044 ('felt', 'like')==<class 'int'> and label is 'pos'
#    0.044 reality==<class 'int'> and label is 'neg'
#   -0.044 i'd==<class 'int'> and label is 'pos'
#    0.044 game==<class 'int'> and label is 'neg'
#    0.044 theory==<class 'int'> and label is 'pos'
#   -0.044 someone==<class 'int'> and label is 'pos'
#   -0.044 you'll==<class 'int'> and label is 'neg'
#    0.044 ('first', 'time')==<class 'int'> and label is 'pos'
#    0.043 understanding==<class 'int'> and label is 'pos'
#    0.043 nothing==<class 'int'> and label is 'neg'
#    0.043 approach==<class 'int'> and label is 'pos'
#    0.043 doubt==<class 'int'> and label is 'neg'
#   -0.043 nothing==<class 'int'> and label is 'pos'
#    0.043 realize==<class 'int'> and label is 'pos'
#    0.043 didn't==<class 'int'> and label is 'neg'
#   -0.043 simple==<class 'int'> and label is 'neg'
#    0.043 later==<class 'int'> and label is 'pos'
#   -0.043 although==<class 'int'> and label is 'neg'
#    0.043 ("don't", 'think')==<class 'int'> and label is 'neg'
#   -0.042 plot==<class 'int'> and label is 'pos'
#   -0.042 money==<class 'int'> and label is 'pos'
#    0.042 left==<class 'int'> and label is 'neg'
#    0.042 detail==<class 'int'> and label is 'pos'
#    0.042 particularly==<class 'int'> and label is 'pos'
#    0.042 trying==<class 'int'> and label is 'neg'
#    0.042 love==<class 'int'> and label is 'pos'
#    0.042 ('would', 'recommend', 'book')==<class 'int'> and label is 'neg'
#    0.042 system==<class 'int'> and label is 'pos'
#    0.042 don't==<class 'int'> and label is 'neg'
#   -0.042 ('book', 'could')==<class 'int'> and label is 'pos'
#   -0.042 family==<class 'int'> and label is 'neg'
#    0.042 enjoy==<class 'int'> and label is 'pos'
#    0.042 political==<class 'int'> and label is 'pos'
#    0.042 evidence==<class 'int'> and label is 'neg'
#   -0.041 everything==<class 'int'> and label is 'neg'
#   -0.041 wasn't==<class 'int'> and label is 'pos'
#   -0.041 pages==<class 'int'> and label is 'pos'
#   -0.041 got==<class 'int'> and label is 'pos'
#   -0.041 interesting==<class 'int'> and label is 'pos'
#    0.041 public==<class 'int'> and label is 'pos'
#    0.041 along==<class 'int'> and label is 'pos'
#    0.041 business==<class 'int'> and label is 'pos'
#    0.041 experience==<class 'int'> and label is 'pos'
#    0.041 small==<class 'int'> and label is 'pos'
#    0.040 interested==<class 'int'> and label is 'neg'
#   -0.040 ('book', 'even')==<class 'int'> and label is 'neg'
#   -0.040 intelligence==<class 'int'> and label is 'pos'
#    0.040 extremely==<class 'int'> and label is 'neg'
#    0.040 got==<class 'int'> and label is 'neg'
#   -0.040 five==<class 'int'> and label is 'neg'
#    0.040 seems==<class 'int'> and label is 'neg'
#   -0.040 seem==<class 'int'> and label is 'pos'
#    0.040 already==<class 'int'> and label is 'neg'
#   -0.040 gave==<class 'int'> and label is 'pos'
#    0.040 ("i've", 'read')==<class 'int'> and label is 'neg'
#    0.040 great==<class 'int'> and label is 'pos'
#    0.040 individual==<class 'int'> and label is 'pos'
#    0.039 order==<class 'int'> and label is 'pos'
#    0.039 analysis==<class 'int'> and label is 'neg'
#    0.039 i'm==<class 'int'> and label is 'neg'
#    0.039 number==<class 'int'> and label is 'neg'
#    0.039 best==<class 'int'> and label is 'pos'
#    0.038 reviews==<class 'int'> and label is 'neg'
#    0.038 evil==<class 'int'> and label is 'neg'
#    0.038 group==<class 'int'> and label is 'neg'
#    0.038 facts==<class 'int'> and label is 'neg'
#    0.038 seen==<class 'int'> and label is 'pos'
#    0.038 cannot==<class 'int'> and label is 'pos'
#    0.038 either==<class 'int'> and label is 'neg'
#    0.038 expect==<class 'int'> and label is 'neg'
#   -0.038 lives==<class 'int'> and label is 'neg'
#    0.038 help==<class 'int'> and label is 'pos'

# %%
# model1 = first_pass(train_xml, test_xml, 200)
# with open("model" + str(round(random.random(),4)) + ".txt", "wb") as fp:
#     pickle.dump(model1, fp)
# best_feats = find_best_feats(model1, 400)

# model2 = second_pass(train_xml, test_xml, best_feats)

# %%
test_ID
# Out:
# '\n1417725184:tremendous:fred_franklin\n'
